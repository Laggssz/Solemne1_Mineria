# %% [markdown]
# <a href="https://colab.research.google.com/github/Laggssz/Solemne1_Mineria/blob/main/Minerioa_New_South_Wales_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Libreria y Cliente Google

# %% [markdown]
# Realizamos lo mismo para las zonas New Sowth Wales y South Australia

# %%
import numpy as np
import pandas as pd
from google.cloud import bigquery
import matplotlib.pyplot as plt
from datetime import datetime

# %%
client = bigquery.Client()

# %%
from google.colab import auth
auth.authenticate_user()

# %%
dataset_ref = client.dataset("covid19_vaccination_search_insights" , project = "bigquery-public-data")

# %%
dataset = client.get_dataset(dataset_ref)

# %%
tables = list(client.list_tables(dataset))

# %%
for table in tables:
  print(table.table_id)
# Out:
# covid19_vaccination_search_insights

# %%
tablref = dataset_ref.table("covid19_vaccination_search_insights")
table = client.get_table(tablref)

# %% [markdown]
# #Visualizacion Preelimiinar de los datos

# %%
 client.list_rows(table, max_results=3000).to_dataframe()#.iloc[100:101]
# Out:
#             date country_region country_region_code       sub_region_1  \
# 0     2022-04-25      Australia                  AU  Western Australia
# 1     2022-03-07      Australia                  AU  Western Australia
# 2     2021-09-27      Australia                  AU  Western Australia
# 3     2021-11-01      Australia                  AU  Western Australia
# 4     2021-05-31      Australia                  AU  Western Australia
# ...          ...            ...                 ...                ...
# 2995  2021-06-21      Australia                  AU    New South Wales
# 2996  2022-05-02      Australia                  AU    New South Wales
# 2997  2022-07-25      Australia                  AU    New South Wales
# 2998  2022-11-14      Australia                  AU    New South Wales
# 2999  2023-07-24      Australia                  AU    New South Wales
#
#      sub_region_1_code           sub_region_2 sub_region_2_code sub_region_3  \
# 0                AU-WA       Shire of Toodyay              None         None
# 1                AU-WA       Shire of Toodyay              None         None
# 2                AU-WA       Shire of Toodyay              None         None
# 3                AU-WA       Shire of Toodyay              None         None
# 4                AU-WA       Shire of Toodyay              None         None
# ...                ...                    ...               ...          ...
# 2995            AU-NSW  Port Stephens Council              None         None
# 2996            AU-NSW  Port Stephens Council              None         None
# 2997            AU-NSW  Port Stephens Council              None         None
# 2998            AU-NSW  Port Stephens Council              None         None
# 2999            AU-NSW  Port Stephens Council              None         None
#
#      sub_region_3_code                     place_id  sni_covid19_vaccination  \
# 0                 None  ChIJ--guQW4ozSsRbePnYkBlnDU                   27.924
# 1                 None  ChIJ--guQW4ozSsRbePnYkBlnDU                   46.850
# 2                 None  ChIJ--guQW4ozSsRbePnYkBlnDU                   68.984
# 3                 None  ChIJ--guQW4ozSsRbePnYkBlnDU                   70.422
# 4                 None  ChIJ--guQW4ozSsRbePnYkBlnDU                   29.903
# ...                ...                          ...                      ...
# 2995              None  ChIJ0Tt7ebB6c2sREnSb-VieKEg                   48.788
# 2996              None  ChIJ0Tt7ebB6c2sREnSb-VieKEg                   13.215
# 2997              None  ChIJ0Tt7ebB6c2sREnSb-VieKEg                   11.409
# 2998              None  ChIJ0Tt7ebB6c2sREnSb-VieKEg                    6.643
# 2999              None  ChIJ0Tt7ebB6c2sREnSb-VieKEg                    3.075
#
#       sni_vaccination_intent  sni_safety_side_effects
# 0                     16.237                      NaN
# 1                     24.868                      NaN
# 2                     26.404                      NaN
# 3                     36.902                      NaN
# 4                        NaN                      NaN
# ...                      ...                      ...
# 2995                  20.979                    6.561
# 2996                   7.543                    1.124
# 2997                   6.828                    1.279
# 2998                   3.584                      NaN
# 2999                   1.299                      NaN
#
# [3000 rows x 13 columns]

# %% [markdown]
# # Graficos para New South Wales ~ Vacunacion

# %%
rows = client.list_rows(table)

Results = []
contador = 0
fechas_un = set()

for row in rows:
    if contador >= 70:
        break
    if row[3] == "New South Wales":
        fecha = row[0]
        Vac = row[10]
        if fecha is not None and Vac is not None and fecha not in fechas_un:
            Results.append((fecha, Vac))
            fechas_un.add(fecha)
            contador += 1


results_or = sorted(Results, key=lambda x: x[0])
fechas = [x[0] for x in results_or]
Vacunas = [x[1] for x in results_or]

print("Fechas:", fechas)
print("Vacunaciones:", Vacunas)
# Out:
# Fechas: [datetime.date(2021, 1, 4), datetime.date(2021, 1, 18), datetime.date(2021, 1, 25), datetime.date(2021, 2, 1), datetime.date(2021, 3, 29), datetime.date(2021, 4, 19), datetime.date(2021, 5, 17), datetime.date(2021, 5, 24), datetime.date(2021, 6, 14), datetime.date(2021, 6, 21), datetime.date(2021, 6, 28), datetime.date(2021, 7, 12), datetime.date(2021, 7, 19), datetime.date(2021, 8, 2), datetime.date(2021, 8, 23), datetime.date(2021, 9, 6), datetime.date(2021, 10, 11), datetime.date(2021, 10, 18), datetime.date(2021, 11, 1), datetime.date(2021, 11, 8), datetime.date(2021, 12, 6), datetime.date(2021, 12, 13), datetime.date(2022, 1, 17), datetime.date(2022, 1, 31), datetime.date(2022, 2, 28), datetime.date(2022, 3, 14), datetime.date(2022, 3, 28), datetime.date(2022, 4, 4), datetime.date(2022, 5, 23), datetime.date(2022, 5, 30), datetime.date(2022, 6, 6), datetime.date(2022, 6, 27), datetime.date(2022, 7, 11), datetime.date(2022, 7, 25), datetime.date(2022, 8, 1), datetime.date(2022, 8, 8), datetime.date(2022, 8, 15), datetime.date(2022, 8, 22), datetime.date(2022, 9, 5), datetime.date(2022, 9, 12), datetime.date(2022, 9, 19), datetime.date(2022, 9, 26), datetime.date(2022, 10, 10), datetime.date(2022, 10, 24), datetime.date(2022, 11, 21), datetime.date(2022, 11, 28), datetime.date(2022, 12, 19), datetime.date(2022, 12, 26), datetime.date(2023, 1, 30), datetime.date(2023, 2, 6), datetime.date(2023, 2, 13), datetime.date(2023, 3, 27), datetime.date(2023, 4, 3), datetime.date(2023, 4, 10), datetime.date(2023, 5, 8), datetime.date(2023, 5, 15), datetime.date(2023, 6, 19), datetime.date(2023, 7, 24), datetime.date(2023, 8, 14), datetime.date(2023, 9, 18), datetime.date(2023, 10, 2), datetime.date(2023, 10, 9), datetime.date(2023, 10, 23), datetime.date(2023, 11, 6), datetime.date(2023, 11, 13), datetime.date(2023, 11, 20), datetime.date(2023, 11, 27), datetime.date(2024, 1, 8), datetime.date(2024, 1, 15), datetime.date(2024, 1, 22)]
# Vacunaciones: [13.597, 9.552, 9.208, 8.201, 26.043, 18.519, 36.092, 41.481, 43.606, 61.499, 87.559, 86.195, 110.262, 144.937, 168.528, 154.129, 166.327, 108.452, 73.967, 57.625, 44.592, 60.154, 65.028, 34.627, 19.248, 20.597, 19.887, 20.379, 14.355, 11.811, 11.604, 12.661, 24.769, 11.746, 10.491, 9.442, 9.596, 8.024, 6.395, 7.382, 5.982, 6.521, 9.395, 6.9, 7.561, 7.824, 7.506, 6.757, 5.484, 9.715, 7.924, 6.572, 6.887, 8.153, 6.526, 6.169, 5.581, 3.766, 3.201, 3.164, 3.521, 3.198, 3.066, 4.599, 5.123, 7.166, 4.754, 6.097, 3.702, 3.114]

# %%
fechas_str = [fecha.strftime("%Y-%m-%d") for fecha in fechas]


plt.figure(figsize=(10, 6))
plt.plot(fechas_str, Vacunas, marker='o', linestyle='-' , color = 'firebrick')
plt.title('~ Vacunación en "New South Wales" ~ ')
plt.xlabel('Fecha - AA - MM - DD')
plt.ylabel('Vacunacion covid 19')
plt.xticks(fechas_str[::5], rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Graficos para New South Wales ~ Intencion

# %%
rows = client.list_rows(table)
Resuls1 = []
contador = 0
fechas_un1 = set()

for row in rows:
    if contador >= 70:
        break
    if row[3] == "New South Wales":
        fecha = row[0]
        Intencion1 = row[11]
        if fecha is not None and Intencion1 is not None and fecha not in fechas_un1:
            Resuls1.append((fecha, Intencion1))
            fechas_un1.add(fecha)
            contador += 1


resultados_or1 = sorted(Resuls1, key=lambda x: x[0])
fechas1 = [x[0] for x in resultados_or1 if x[0] is not None]
Intencion = [x[1] for x in resultados_or1 if x[1] is not None]


print("Fechas:", fechas1)
print("Intenciones:", Intencion)
# Out:
# Fechas: [datetime.date(2021, 1, 4), datetime.date(2021, 1, 18), datetime.date(2021, 1, 25), datetime.date(2021, 2, 1), datetime.date(2021, 3, 15), datetime.date(2021, 3, 29), datetime.date(2021, 4, 19), datetime.date(2021, 5, 17), datetime.date(2021, 5, 24), datetime.date(2021, 6, 14), datetime.date(2021, 6, 21), datetime.date(2021, 6, 28), datetime.date(2021, 7, 12), datetime.date(2021, 7, 19), datetime.date(2021, 7, 26), datetime.date(2021, 8, 2), datetime.date(2021, 8, 23), datetime.date(2021, 9, 6), datetime.date(2021, 10, 11), datetime.date(2021, 10, 18), datetime.date(2021, 11, 1), datetime.date(2021, 11, 8), datetime.date(2021, 12, 6), datetime.date(2021, 12, 13), datetime.date(2022, 1, 3), datetime.date(2022, 1, 17), datetime.date(2022, 1, 31), datetime.date(2022, 2, 28), datetime.date(2022, 3, 14), datetime.date(2022, 3, 28), datetime.date(2022, 4, 4), datetime.date(2022, 5, 2), datetime.date(2022, 5, 23), datetime.date(2022, 5, 30), datetime.date(2022, 6, 6), datetime.date(2022, 6, 27), datetime.date(2022, 7, 11), datetime.date(2022, 7, 25), datetime.date(2022, 8, 1), datetime.date(2022, 8, 8), datetime.date(2022, 8, 15), datetime.date(2022, 8, 22), datetime.date(2022, 9, 5), datetime.date(2022, 9, 12), datetime.date(2022, 9, 19), datetime.date(2022, 9, 26), datetime.date(2022, 10, 10), datetime.date(2022, 10, 24), datetime.date(2022, 11, 21), datetime.date(2022, 11, 28), datetime.date(2022, 12, 19), datetime.date(2022, 12, 26), datetime.date(2023, 1, 30), datetime.date(2023, 2, 6), datetime.date(2023, 2, 13), datetime.date(2023, 2, 20), datetime.date(2023, 3, 27), datetime.date(2023, 4, 3), datetime.date(2023, 4, 10), datetime.date(2023, 5, 8), datetime.date(2023, 5, 15), datetime.date(2023, 6, 19), datetime.date(2023, 7, 24), datetime.date(2023, 8, 14), datetime.date(2023, 11, 6), datetime.date(2023, 11, 13), datetime.date(2023, 11, 20), datetime.date(2023, 11, 27), datetime.date(2023, 12, 4), datetime.date(2024, 1, 8)]
# Intenciones: [3.785, 2.439, 2.704, 2.421, 20.802, 13.758, 6.715, 15.567, 18.661, 17.404, 25.175, 38.048, 36.679, 47.701, 48.508, 62.136, 77.612, 64.996, 65.327, 40.339, 35.291, 26.26, 23.043, 34.245, 52.804, 34.863, 16.96, 9.128, 9.851, 10.472, 10.953, 7.493, 7.986, 6.25, 6.12, 6.672, 15.667, 5.585, 4.979, 4.252, 4.838, 3.749, 2.805, 3.85, 2.778, 2.846, 3.779, 3.037, 2.979, 2.859, 3.824, 3.185, 2.453, 4.745, 4.056, 5.111, 3.477, 3.584, 4.355, 2.937, 2.566, 2.209, 1.784, 1.582, 1.752, 2.197, 3.016, 2.119, 2.2, 3.042]

# %%
#fecha_limite = datetime(2022, 4, 11)

fechas_str1 = [fecha.strftime("%Y-%m-%d") for fecha in fechas1]


plt.figure(figsize=(10, 6))
plt.plot(fechas_str1, Intencion, marker='o', linestyle='-' , color = 'maroon')
plt.title('~ Intencion en "New South Wales" ~ ')
plt.xlabel('Fecha - AA - MM - DD')
plt.ylabel('Intencion covid 19')
plt.xticks(fechas_str[::5], rotation=45)
plt.grid(True)
plt.tight_layout()



#plt.xlim(fechas_str1[0], fecha_limite.strftime("%Y-%m-%d"))

# %% [markdown]
# # Safety Side New South Wales Australia

# %%
rows = client.list_rows(table)

Results3 = []
contador = 0


for row in rows:
    if contador >= 70:
        break
    if row[3] == "New South Wales":
        fecha3 = row[0]
        Safe = row[12]
        if fecha3 is not None and Safe is not None:
            Results3.append((fecha3, Safe))
            contador += 1

results_or3 = sorted(Results3, key=lambda x: x[0])
fechas3 = [x[0] for x in results_or3 if x[0] is not None]
Safety = [x[1] for x in results_or3 if x[1] is not None]


print("Fechas:", fechas3)
print("Safety", Safety)
# Out:
# Fechas: [datetime.date(2021, 2, 15), datetime.date(2021, 2, 22), datetime.date(2021, 3, 8), datetime.date(2021, 3, 15), datetime.date(2021, 3, 22), datetime.date(2021, 3, 29), datetime.date(2021, 4, 5), datetime.date(2021, 4, 12), datetime.date(2021, 4, 19), datetime.date(2021, 4, 26), datetime.date(2021, 5, 3), datetime.date(2021, 5, 10), datetime.date(2021, 5, 17), datetime.date(2021, 5, 24), datetime.date(2021, 5, 31), datetime.date(2021, 6, 7), datetime.date(2021, 6, 14), datetime.date(2021, 6, 21), datetime.date(2021, 6, 28), datetime.date(2021, 7, 5), datetime.date(2021, 7, 12), datetime.date(2021, 7, 19), datetime.date(2021, 7, 26), datetime.date(2021, 8, 2), datetime.date(2021, 8, 9), datetime.date(2021, 8, 16), datetime.date(2021, 8, 23), datetime.date(2021, 8, 30), datetime.date(2021, 9, 6), datetime.date(2021, 9, 13), datetime.date(2021, 9, 20), datetime.date(2021, 9, 27), datetime.date(2021, 10, 4), datetime.date(2021, 10, 4), datetime.date(2021, 10, 11), datetime.date(2021, 10, 11), datetime.date(2021, 10, 18), datetime.date(2021, 10, 25), datetime.date(2021, 11, 1), datetime.date(2021, 11, 8), datetime.date(2021, 11, 15), datetime.date(2021, 11, 22), datetime.date(2021, 11, 29), datetime.date(2021, 12, 6), datetime.date(2021, 12, 13), datetime.date(2021, 12, 20), datetime.date(2021, 12, 27), datetime.date(2022, 1, 3), datetime.date(2022, 1, 10), datetime.date(2022, 1, 17), datetime.date(2022, 1, 24), datetime.date(2022, 1, 31), datetime.date(2022, 2, 7), datetime.date(2022, 2, 14), datetime.date(2022, 2, 21), datetime.date(2022, 2, 28), datetime.date(2022, 3, 7), datetime.date(2022, 3, 14), datetime.date(2022, 3, 21), datetime.date(2022, 3, 28), datetime.date(2022, 4, 4), datetime.date(2022, 4, 11), datetime.date(2022, 4, 25), datetime.date(2022, 5, 2), datetime.date(2022, 5, 9), datetime.date(2022, 7, 4), datetime.date(2022, 7, 11), datetime.date(2022, 7, 18), datetime.date(2022, 7, 25), datetime.date(2022, 8, 1)]
# Safety [3.347, 2.358, 2.139, 2.548, 3.346, 4.212, 4.707, 4.065, 4.443, 4.251, 5.893, 6.662, 6.994, 7.831, 6.219, 6.309, 7.264, 8.72, 11.845, 11.494, 11.443, 14.802, 16.083, 19.906, 20.842, 20.165, 22.489, 21.83, 22.085, 20.222, 19.661, 16.153, 12.401, 8.265, 9.926, 6.716, 8.029, 6.362, 5.55, 4.043, 3.847, 2.472, 2.146, 2.043, 2.513, 2.905, 2.856, 4.543, 5.453, 5.171, 4.741, 3.581, 3.527, 2.601, 2.369, 1.925, 2.34, 2.093, 2.207, 2.051, 1.546, 2.23, 1.444, 1.595, 1.274, 1.489, 2.055, 2.04, 1.422, 1.621]

# %%
fecha_limite = datetime(2022, 7, 11)

fechas_str3 = [fecha.strftime("%Y-%m-%d") for fecha in fechas3]

plt.figure(figsize=(10, 6))
plt.plot(fechas_str3, Safety, marker='o', linestyle='-', color='darkolivegreen')
plt.title('~ Efectos Secundarios  en "New South Wales" ~ ')
plt.xlabel('Fecha - Año - Mes - Día')
plt.ylabel('Efectos Secundarios Seguros')
plt.xticks(fechas_str[::4], rotation=45)
plt.grid(True)
plt.tight_layout()

plt.xlim(fechas_str3[0], fecha_limite.strftime("%Y-%m-%d"))

plt.show()

# %% [markdown]
# # Union Graficos "New South Wales"

# %%
fechas_str1 = [fecha.strftime("%Y-%m-%d") for fecha in fechas1]


plt.figure(figsize=(10, 6))
plt.plot(fechas_str1, Intencion, marker='o', linestyle='-' , color = 'darkslategrey',  label='Intención' )
plt.plot(fechas_str, Vacunas, marker='o', linestyle='-' , color = 'darkslateblue' , label='Vacunacion' )
plt.title('~ Vacunación  VS Intencion en "New South Wales" ~ ')
plt.xlabel('Fecha - AA - MM - DD')
plt.ylabel('Num de Vac/Int')
plt.xticks(fechas_str[::5], rotation=45)
plt.grid(True)
plt.legend()
plt.tight_layout()

# %%
fecha_liminf = datetime(2021, 4, 5)
fecha_limsup = datetime(2022, 2, 28)

fechas_str1_filtered = []
Intencion_fil = []
for fecha, dato in zip(fechas_str1, Intencion):
    fecha_dt = datetime.strptime(fecha, "%Y-%m-%d")
    if fecha_liminf <= fecha_dt <= fecha_limsup :
        fechas_str1_filtered.append(fecha)
        Intencion_fil.append(dato)

fechas_str_filtered = []
Vacunas_fil= []
for fecha, dato in zip(fechas_str, Vacunas):
    fecha_dt = datetime.strptime(fecha, "%Y-%m-%d")
    if fecha_liminf <= fecha_dt <= fecha_limsup :
        fechas_str_filtered.append(fecha)
        Vacunas_fil.append(dato)


plt.figure(figsize=(10, 6))
plt.plot(fechas_str3, Safety, marker='o', linestyle='-', color='midnightblue')
plt.plot(fechas_str_filtered, Vacunas_fil, marker='o', linestyle='-' , color='darkred', label='Vacunas')
plt.title('~ Vacunación  VS Intencion en "Western Australia" ~ ')
plt.xlabel('Fecha - AA - MM - DD')
plt.ylabel('Num de Vac/Int')
plt.xticks( rotation=45)
plt.grid(True)
plt.tight_layout()
plt.legend()

plt.show()
